# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('dataset.csv')

# %%
data.shape
# Out:
# (15064, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15064 entries, 0 to 15063
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Cycle_Index                15064 non-null  float64
#  1   Discharge Time (s)         15064 non-null  float64
#  2   Decrement 3.6-3.4V (s)     15064 non-null  float64
#  3   Max. Voltage Dischar. (V)  15064 non-null  float64
#  4   Min. Voltage Charg. (V)    15064 non-null  float64
#  5   Time at 4.15V (s)          15064 non-null  float64
#  6   Time constant current (s)  15064 non-null  float64
#  7   Charging time (s)          15064 non-null  float64
#  8   RUL                        15064 non-null  int64
# dtypes: float64(8), int64(1)
# memory usage: 1.0 MB

# %%
data.corr()
# Out:
#                            Cycle_Index  Discharge Time (s)  \
# Cycle_Index                   1.000000           -0.011925
# Discharge Time (s)           -0.011925            1.000000
# Decrement 3.6-3.4V (s)       -0.012090            0.444984
# Max. Voltage Dischar. (V)    -0.782859            0.349161
# Min. Voltage Charg. (V)       0.759850           -0.239410
# Time at 4.15V (s)            -0.176486            0.776720
# Time constant current (s)    -0.040622            0.912536
# Charging time (s)            -0.018305            0.935544
# RUL                          -0.999756            0.011957
#
#                            Decrement 3.6-3.4V (s)  Max. Voltage Dischar. (V)  \
# Cycle_Index                             -0.012090                  -0.782859
# Discharge Time (s)                       0.444984                   0.349161
# Decrement 3.6-3.4V (s)                   1.000000                   0.199470
# Max. Voltage Dischar. (V)                0.199470                   1.000000
# Min. Voltage Charg. (V)                 -0.132765                  -0.718182
# Time at 4.15V (s)                        0.477091                   0.446070
# Time constant current (s)                0.343228                   0.286886
# Charging time (s)                        0.371610                   0.269009
# RUL                                      0.011998                   0.782800
#
#                            Min. Voltage Charg. (V)  Time at 4.15V (s)  \
# Cycle_Index                               0.759850          -0.176486
# Discharge Time (s)                       -0.239410           0.776720
# Decrement 3.6-3.4V (s)                   -0.132765           0.477091
# Max. Voltage Dischar. (V)                -0.718182           0.446070
# Min. Voltage Charg. (V)                   1.000000          -0.344098
# Time at 4.15V (s)                        -0.344098           1.000000
# Time constant current (s)                -0.216840           0.568922
# Charging time (s)                        -0.200423           0.676859
# RUL                                      -0.759805           0.176514
#
#                            Time constant current (s)  Charging time (s)  \
# Cycle_Index                                -0.040622          -0.018305
# Discharge Time (s)                          0.912536           0.935544
# Decrement 3.6-3.4V (s)                      0.343228           0.371610
# Max. Voltage Dischar. (V)                   0.286886           0.269009
# Min. Voltage Charg. (V)                    -0.216840          -0.200423
# Time at 4.15V (s)                           0.568922           0.676859
# Time constant current (s)                   1.000000           0.953522
# Charging time (s)                           0.953522           1.000000
# RUL                                         0.040675           0.018299
#
#                                 RUL
# Cycle_Index               -0.999756
# Discharge Time (s)         0.011957
# Decrement 3.6-3.4V (s)     0.011998
# Max. Voltage Dischar. (V)  0.782800
# Min. Voltage Charg. (V)   -0.759805
# Time at 4.15V (s)          0.176514
# Time constant current (s)  0.040675
# Charging time (s)          0.018299
# RUL                        1.000000

# %%
data.describe()
# Out:
#         Cycle_Index  Discharge Time (s)  Decrement 3.6-3.4V (s)  \
# count  15064.000000        15064.000000            15064.000000
# mean     556.155005         4581.273960             1239.784672
# std      322.378480        33144.012077            15039.589269
# min        1.000000            8.690000          -397645.908000
# 25%      271.000000         1169.310000              319.600000
# 50%      560.000000         1557.250000              439.239471
# 75%      833.000000         1908.000000              600.000000
# max     1134.000000       958320.370000           406703.768000
#
#        Max. Voltage Dischar. (V)  Min. Voltage Charg. (V)  Time at 4.15V (s)  \
# count               15064.000000             15064.000000       15064.000000
# mean                    3.908176                 3.577904        3768.336171
# std                     0.091003                 0.123695        9129.552477
# min                     3.043000                 3.022000        -113.584000
# 25%                     3.846000                 3.488000        1828.884179
# 50%                     3.906000                 3.574000        2930.203500
# 75%                     3.972000                 3.663000        4088.326500
# max                     4.363000                 4.379000      245101.117000
#
#        Time constant current (s)  Charging time (s)           RUL
# count               15064.000000       15064.000000  15064.000000
# mean                 5461.266970       10066.496204    554.194172
# std                 25155.845202       26415.354121    322.434514
# min                     5.980000           5.980000      0.000000
# 25%                  2564.310000        7841.922500    277.000000
# 50%                  3824.260000        8320.415000    551.000000
# 75%                  5012.350000        8763.282500    839.000000
# max                880728.100000      880728.100000   1133.000000

# %%
data['RUL'].mean()
# Out:
# 554.1941715347849

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for Cycle Index and RUL
cycle_index = np.linspace(0, 1000, 50)  # 50 evenly spaced points from 0 to 1000
rul = 1000 - cycle_index  # RUL decreases linearly with Cycle Index

# Create the plot
plt.figure(figsize=(8, 4))
plt.plot(cycle_index, rul, label='Cycle Index vs. RUL')
plt.title("Cycle Index vs. Remaining Useful Life (RUL)")
plt.xlabel("Cycle Index")
plt.ylabel("Remaining Useful Life (RUL)")
plt.grid(True)
plt.legend()
plt.savefig('info.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn style for better visualization
sns.set(style="whitegrid")

# Assuming the DataFrame is loaded into a variable named 'data'
for col in data.columns:
    plt.figure(figsize=(8, 6))
    plt.hist(data[col].dropna(), bins=20, edgecolor='black', alpha=0.7)  # Handle NaN values if present
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    # Save each plot as a separate image
    plt.savefig(f'{col}_distribution.png', dpi=300, bbox_inches='tight')
    plt.close()  # Close the figure to prevent overlap

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU
from sklearn.model_selection import train_test_split

# Load your dataset (adjust file path as needed)
data = pd.read_csv('dataset.csv')  # Replace with your actual file

# Feature selection: Drop 'RUL' for input features
X = data.drop('RUL', axis=1).values
y = data['RUL'].values

# Normalize features (MinMax scaling between 0 and 1)
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# Reshape the data into time series format for RNN (samples, timesteps, features)
TIME_STEPS = 10  # Window size
def create_sequences(X, y, time_steps=TIME_STEPS):
    X_seq, y_seq = [], []
    for i in range(len(X) - time_steps):
        X_seq.append(X[i:i + time_steps])
        y_seq.append(y[i + time_steps])
    return np.array(X_seq), np.array(y_seq)

X_seq, y_seq = create_sequences(X, y)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

# Define the RNN model
model_rnn = Sequential()
model_rnn.add(SimpleRNN(64, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model_rnn.add(Dense(32, activation='relu'))
model_rnn.add(Dense(1))  # Output layer for RUL prediction

# Compile the model
model_rnn.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
history = model_rnn.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the model on test data
test_loss, test_mae = model_rnn.evaluate(X_test, y_test)
print(f'Test MAE: {test_mae}')

# Predict the RUL for test data
y_pred = model_rnn.predict(X_test)

# Example of comparing predicted vs actual values
# Out:
# Epoch 1/50
# C:\Users\saravanan013\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 208703.7500 - mae: 336.4924 - val_loss: 6600.0630 - val_mae: 31.3884
# Epoch 2/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9041.5654 - mae: 33.1291 - val_loss: 5365.0991 - val_mae: 21.6093
# Epoch 3/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7209.4873 - mae: 27.8126 - val_loss: 5243.9424 - val_mae: 30.5534
# Epoch 4/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5745.5879 - mae: 26.3411 - val_loss: 4688.4961 - val_mae: 24.0485
# Epoch 5/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4924.8125 - mae: 24.5790 - val_loss: 4493.7798 - val_mae: 25.1285
# Epoch 6/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5461.2998 - mae: 24.7933 - val_loss: 4262.8438 - val_mae: 25.6204
# Epoch 7/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5848.3042 - mae: 27.3967 - val_loss: 4428.8315 - val_mae: 31.6506
# Epoch 8/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5040.0020 - mae: 25.2732 - val_loss: 3968.1401 - val_mae: 28.6373
# Epoch 9/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4518.3696 - mae: 21.5580 - val_loss: 3972.9795 - val_mae: 28.4785
# Epoch 10/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4967.5469 - mae: 23.6836 - val_loss: 3617.8965 - val_mae: 24.7332
# Epoch 11/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4205.5640 - mae: 24.4520 - val_loss: 3048.4446 - val_mae: 18.7105
# Epoch 12/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3438.0657 - mae: 22.0391 - val_loss: 3336.4172 - val_mae: 30.0897
# Epoch 13/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3909.5320 - mae: 29.4385 - val_loss: 2588.4929 - val_mae: 15.9981
# Epoch 14/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3814.7627 - mae: 25.5039 - val_loss: 2691.7292 - val_mae: 17.0629
# Epoch 15/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2603.3425 - mae: 18.8643 - val_loss: 2249.2908 - val_mae: 14.7225
# Epoch 16/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2633.3604 - mae: 18.8802 - val_loss: 2319.4609 - val_mae: 17.6986
# Epoch 17/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2466.7402 - mae: 18.5543 - val_loss: 2216.8909 - val_mae: 20.3058
# Epoch 18/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2117.1963 - mae: 19.1028 - val_loss: 1892.2197 - val_mae: 12.9123
# Epoch 19/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2013.1360 - mae: 15.6341 - val_loss: 3581.4875 - val_mae: 27.7898
# Epoch 20/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2532.8203 - mae: 20.9142 - val_loss: 1853.3102 - val_mae: 18.3327
# Epoch 21/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1801.2008 - mae: 14.7081 - val_loss: 1862.0583 - val_mae: 16.6986
# Epoch 22/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1825.4536 - mae: 16.8450 - val_loss: 2702.0046 - val_mae: 35.4772
# Epoch 23/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1973.6423 - mae: 19.4476 - val_loss: 1574.7018 - val_mae: 13.5082
# Epoch 24/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1000.0156 - mae: 12.2497 - val_loss: 1784.7999 - val_mae: 22.7046
# Epoch 25/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1930.6641 - mae: 16.6040 - val_loss: 1865.5667 - val_mae: 18.7269
# Epoch 26/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1135.3159 - mae: 13.6864 - val_loss: 1356.7441 - val_mae: 12.0072
# Epoch 27/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 977.9277 - mae: 11.7197 - val_loss: 1684.8682 - val_mae: 23.4642
# Epoch 28/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1141.7228 - mae: 12.4093 - val_loss: 1191.2288 - val_mae: 11.7789
# Epoch 29/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1398.2227 - mae: 14.6080 - val_loss: 1448.0004 - val_mae: 14.6756
# Epoch 30/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1308.1703 - mae: 13.2356 - val_loss: 1256.7631 - val_mae: 10.8849
# Epoch 31/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 964.6110 - mae: 13.7894 - val_loss: 1097.3207 - val_mae: 11.1630
# Epoch 32/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 757.2934 - mae: 11.4454 - val_loss: 945.6697 - val_mae: 8.5770
# Epoch 33/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1505.8099 - mae: 14.3626 - val_loss: 1216.4203 - val_mae: 13.2817
# Epoch 34/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 493.5266 - mae: 9.6472 - val_loss: 1063.3252 - val_mae: 15.9270
# Epoch 35/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 767.4687 - mae: 13.3775 - val_loss: 941.7437 - val_mae: 10.9094
# Epoch 36/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 591.0774 - mae: 10.5826 - val_loss: 881.1017 - val_mae: 8.4825
# Epoch 37/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 715.0147 - mae: 12.5829 - val_loss: 880.4136 - val_mae: 8.9546
# Epoch 38/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 620.5260 - mae: 11.4487 - val_loss: 779.3766 - val_mae: 8.3722
# Epoch 39/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 689.2713 - mae: 10.7567 - val_loss: 25067.1074 - val_mae: 142.5965
# Epoch 40/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6843.9395 - mae: 43.0299 - val_loss: 864.3504 - val_mae: 10.6831
# Epoch 41/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 498.8558 - mae: 9.4138 - val_loss: 801.6663 - val_mae: 10.2362
# Epoch 42/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 830.9927 - mae: 11.1866 - val_loss: 776.1006 - val_mae: 8.5259
# Epoch 43/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1490.2566 - mae: 12.1005 - val_loss: 810.2216 - val_mae: 8.3895
# Epoch 44/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 413.2261 - mae: 8.9920 - val_loss: 777.3466 - val_mae: 10.6758
# Epoch 45/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 632.1914 - mae: 10.4661 - val_loss: 762.2049 - val_mae: 9.0898
# Epoch 46/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 446.1189 - mae: 10.1701 - val_loss: 707.5897 - val_mae: 9.4656
# Epoch 47/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 526.9298 - mae: 11.0403 - val_loss: 630.3278 - val_mae: 7.9335
# Epoch 48/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 466.3894 - mae: 9.2097 - val_loss: 685.1498 - val_mae: 10.4292
# Epoch 49/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 668.2591 - mae: 12.8845 - val_loss: 598.0665 - val_mae: 7.6204
# Epoch 50/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 402.2312 - mae: 9.8457 - val_loss: 806.5604 - val_mae: 16.2664
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1410.5671 - mae: 17.0315
# Test MAE: 16.96889877319336
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Predict the RUL for the test data
y_pred = model_rnn.predict(X_test)

# Flatten the predictions and actual values
y_pred = y_pred.flatten()
y_test = y_test.flatten()

# Calculate standard performance metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Define a custom accuracy metric (percentage of predictions within 10% tolerance of actual value)
tolerance = 0.10  # 10% tolerance
accurate_predictions = np.sum(np.abs(y_test - y_pred) <= tolerance * y_test)
accuracy = accurate_predictions / len(y_test) * 100

# Print all performance metrics
print(f'Mean Squared Error (MSE): {mse:.4f}')
print(f'Mean Absolute Error (MAE): {mae:.4f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.4f}')
print(f'Accuracy (within 10% tolerance): {accuracy:.2f}%')

# Optional: Print the first 10 predictions vs actual values for inspection
print('\nSample Predictions vs Actual Values:')
for i in range(10):
    print(f'Actual: {y_test[i]:.2f}, Predicted: {y_pred[i]:.2f}')
# Out:
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error (MSE): 1361.5190
# Mean Absolute Error (MAE): 16.9689
# Root Mean Squared Error (RMSE): 36.8988
# Accuracy (within 10% tolerance): 92.43%
#
# Sample Predictions vs Actual Values:
# Actual: 192.00, Predicted: 184.64
# Actual: 445.00, Predicted: 438.06
# Actual: 349.00, Predicted: 341.48
# Actual: 515.00, Predicted: 501.05
# Actual: 827.00, Predicted: 786.26
# Actual: 929.00, Predicted: 908.47
# Actual: 1008.00, Predicted: 987.81
# Actual: 273.00, Predicted: 244.43
# Actual: 74.00, Predicted: 77.99
# Actual: 341.00, Predicted: 333.51

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(y_test[:100], label='Actual RUL', marker='o')
plt.plot(y_pred[:100], label='Predicted RUL', marker='x')
plt.title('Battery Life Prediction: Actual vs Predicted RUL')
plt.xlabel('Sample')
plt.ylabel('RUL')
plt.legend()
plt.savefig('RNN.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.model_selection import train_test_split

# Load your dataset (adjust file path as needed)
data = pd.read_csv('dataset.csv')  # Replace with the actual path to your dataset

# Feature selection: Drop 'RUL' for input features
X = data.drop('RUL', axis=1).values
y = data['RUL'].values

# Normalize features (MinMax scaling between 0 and 1)
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# Reshape the data into time series format for LSTM (samples, timesteps, features)
TIME_STEPS = 10  # Window size

def create_sequences(X, y, time_steps=TIME_STEPS):
    X_seq, y_seq = [], []
    for i in range(len(X) - time_steps):
        X_seq.append(X[i:i + time_steps])
        y_seq.append(y[i + time_steps])
    return np.array(X_seq), np.array(y_seq)

X_seq, y_seq = create_sequences(X, y)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

# Define the LSTM model
model_lstm = Sequential()
model_lstm.add(LSTM(64, activation='tanh', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False))
model_lstm.add(Dense(32, activation='relu'))
model_lstm.add(Dense(1))  # Output layer for RUL prediction

# Compile the model
model_lstm.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
history = model_lstm.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the model on the test data
test_loss, test_mae = model_lstm.evaluate(X_test, y_test)
print(f'Test MAE: {test_mae:.4f}')

# Predict the RUL for the test data
y_pred = model_lstm.predict(X_test).flatten()
# Out:
# Epoch 1/50
# C:\Users\saravanan013\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 393451.1562 - mae: 537.6192 - val_loss: 263040.3750 - val_mae: 421.5639
# Epoch 2/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 227618.9375 - mae: 390.0199 - val_loss: 127000.7266 - val_mae: 298.4357
# Epoch 3/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 121135.0703 - mae: 294.9635 - val_loss: 102949.8594 - val_mae: 274.7520
# Epoch 4/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 105511.2031 - mae: 282.1503 - val_loss: 102526.6250 - val_mae: 274.4857
# Epoch 5/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 102786.4219 - mae: 277.8891 - val_loss: 102523.7031 - val_mae: 274.4794
# Epoch 6/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 104084.8203 - mae: 279.5834 - val_loss: 102504.6484 - val_mae: 274.4343
# Epoch 7/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 103886.7578 - mae: 279.4936 - val_loss: 102492.1875 - val_mae: 274.4011
# Epoch 8/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 103366.5938 - mae: 278.1737 - val_loss: 102684.8359 - val_mae: 274.7578
# Epoch 9/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 104751.3906 - mae: 281.4745 - val_loss: 98907.6875 - val_mae: 269.5133
# Epoch 10/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 77842.4141 - mae: 225.2481 - val_loss: 9056.4922 - val_mae: 66.0151
# Epoch 11/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5459.7910 - mae: 43.8178 - val_loss: 1785.8732 - val_mae: 21.9277
# Epoch 12/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1762.2384 - mae: 22.1834 - val_loss: 1287.4797 - val_mae: 22.7336
# Epoch 13/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 936.0370 - mae: 17.9367 - val_loss: 770.7905 - val_mae: 14.8677
# Epoch 14/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 400.9072 - mae: 13.1211 - val_loss: 791.8070 - val_mae: 18.5423
# Epoch 15/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 466.5933 - mae: 13.2546 - val_loss: 587.9537 - val_mae: 14.1729
# Epoch 16/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 502.2440 - mae: 12.2301 - val_loss: 392.1175 - val_mae: 10.3348
# Epoch 17/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 237.6746 - mae: 10.1602 - val_loss: 475.7398 - val_mae: 15.0309
# Epoch 18/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 320.0865 - mae: 11.0950 - val_loss: 323.8446 - val_mae: 10.0624
# Epoch 19/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 342.1699 - mae: 10.9829 - val_loss: 251.7014 - val_mae: 9.0232
# Epoch 20/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 239.3952 - mae: 9.4416 - val_loss: 295.1415 - val_mae: 11.3184
# Epoch 21/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 210.1525 - mae: 9.0430 - val_loss: 203.0262 - val_mae: 8.1011
# Epoch 22/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 185.9451 - mae: 8.7379 - val_loss: 197.6503 - val_mae: 9.2436
# Epoch 23/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 232.6958 - mae: 9.6404 - val_loss: 202.8523 - val_mae: 9.0597
# Epoch 24/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 222.5368 - mae: 8.7132 - val_loss: 156.8696 - val_mae: 7.2016
# Epoch 25/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 170.4998 - mae: 8.1864 - val_loss: 135.5575 - val_mae: 6.6692
# Epoch 26/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 145.9222 - mae: 7.7737 - val_loss: 160.0745 - val_mae: 7.9231
# Epoch 27/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 182.7999 - mae: 9.0147 - val_loss: 139.0410 - val_mae: 8.4789
# Epoch 28/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 120.0432 - mae: 7.3636 - val_loss: 160.9900 - val_mae: 9.5067
# Epoch 29/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 161.9075 - mae: 8.5299 - val_loss: 115.9926 - val_mae: 6.7962
# Epoch 30/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 107.3759 - mae: 7.0776 - val_loss: 150.6196 - val_mae: 8.9371
# Epoch 31/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 159.1383 - mae: 8.7545 - val_loss: 120.7311 - val_mae: 8.4666
# Epoch 32/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 99.6443 - mae: 6.8834 - val_loss: 88.6321 - val_mae: 6.0334
# Epoch 33/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 118.4980 - mae: 7.4382 - val_loss: 135.8926 - val_mae: 8.0501
# Epoch 34/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 104.9463 - mae: 7.3670 - val_loss: 103.8960 - val_mae: 6.8247
# Epoch 35/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 90.8438 - mae: 6.8082 - val_loss: 104.6166 - val_mae: 6.9377
# Epoch 36/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 110.6967 - mae: 7.3849 - val_loss: 85.3533 - val_mae: 5.8771
# Epoch 37/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 108.3023 - mae: 7.2107 - val_loss: 118.8422 - val_mae: 9.2683
# Epoch 38/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 101.1238 - mae: 7.1785 - val_loss: 98.1605 - val_mae: 6.9425
# Epoch 39/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 130.2539 - mae: 7.7711 - val_loss: 145.2203 - val_mae: 8.9607
# Epoch 40/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 90.7134 - mae: 6.5868 - val_loss: 88.7606 - val_mae: 6.9210
# Epoch 41/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 103.7860 - mae: 7.3298 - val_loss: 76.1348 - val_mae: 5.6996
# Epoch 42/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 81.6671 - mae: 6.3138 - val_loss: 74.7202 - val_mae: 5.5404
# Epoch 43/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 79.1036 - mae: 6.1844 - val_loss: 143.8872 - val_mae: 9.0945
# Epoch 44/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 103.4907 - mae: 7.3076 - val_loss: 170.5334 - val_mae: 12.1806
# Epoch 45/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 300.0474 - mae: 9.8997 - val_loss: 385.4774 - val_mae: 10.7140
# Epoch 46/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 294.0145 - mae: 8.5023 - val_loss: 220.2532 - val_mae: 9.9483
# Epoch 47/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 163.0972 - mae: 8.5291 - val_loss: 92.6970 - val_mae: 5.6455
# Epoch 48/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 100.4651 - mae: 6.9170 - val_loss: 248.8851 - val_mae: 13.5876
# Epoch 49/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 111.4591 - mae: 7.3341 - val_loss: 96.8986 - val_mae: 6.9204
# Epoch 50/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 84.8976 - mae: 6.3164 - val_loss: 78.5302 - val_mae: 5.4039
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 79.9108 - mae: 5.2402
# Test MAE: 5.3774
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Predict the RUL for the test data


# Flatten the predictions and actual values
y_pred = y_pred.flatten()
y_test = y_test.flatten()

# Calculate standard performance metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Define a custom accuracy metric (percentage of predictions within 10% tolerance of actual value)
tolerance = 0.10  # 10% tolerance
accurate_predictions = np.sum(np.abs(y_test - y_pred) <= tolerance * y_test)
accuracy = accurate_predictions / len(y_test) * 100

# Print all performance metrics
print(f'Mean Squared Error (MSE): {mse:.4f}')
print(f'Mean Absolute Error (MAE): {mae:.4f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.4f}')
print(f'Accuracy (within 10% tolerance): {accuracy:.2f}%')

# Optional: Print the first 10 predictions vs actual values for inspection
print('\nSample Predictions vs Actual Values:')
for i in range(10):
    print(f'Actual: {y_test[i]:.2f}, Predicted: {y_pred[i]:.2f}')
# Out:
# Mean Squared Error (MSE): 84.6238
# Mean Absolute Error (MAE): 5.3774
# Root Mean Squared Error (RMSE): 9.1991
# Accuracy (within 10% tolerance): 90.93%
#
# Sample Predictions vs Actual Values:
# Actual: 192.00, Predicted: 183.74
# Actual: 445.00, Predicted: 449.57
# Actual: 349.00, Predicted: 349.34
# Actual: 515.00, Predicted: 512.47
# Actual: 827.00, Predicted: 805.26
# Actual: 929.00, Predicted: 923.98
# Actual: 1008.00, Predicted: 1009.78
# Actual: 273.00, Predicted: 249.77
# Actual: 74.00, Predicted: 66.12
# Actual: 341.00, Predicted: 340.29

# %%
num_samples = 100
y_test_limited = y_test[:num_samples]
y_pred_limited = y_pred[:num_samples]

# Plot Actual vs. Predicted values for the limited data
plt.figure(figsize=(10, 6))
plt.plot(y_test_limited, label='Actual RUL', marker='o')
plt.plot(y_pred_limited, label='Predicted RUL', marker='x')
plt.title('Actual vs Predicted RUL (Limited Samples)')
plt.xlabel('Sample Index')
plt.ylabel('RUL')
plt.legend()
plt.grid(True)
plt.savefig('LSTM.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Bidirectional
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load your dataset (adjust the file path as needed)
data = pd.read_csv('dataset.csv')  # Replace with your actual file path

# Feature selection: Drop 'RUL' for input features
X = data.drop('RUL', axis=1).values
y = data['RUL'].values

# Normalize features (MinMax scaling between 0 and 1)
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# Reshape the data into time series format for LSTM (samples, timesteps, features)
TIME_STEPS = 10  # Window size

def create_sequences(X, y, time_steps=TIME_STEPS):
    X_seq, y_seq = [], []
    for i in range(len(X) - time_steps):
        X_seq.append(X[i:i + time_steps])
        y_seq.append(y[i + time_steps])
    return np.array(X_seq), np.array(y_seq)

X_seq, y_seq = create_sequences(X, y)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

# Define the Bidirectional LSTM model
model_bilstm = Sequential()
model_bilstm.add(Bidirectional(LSTM(64, activation='tanh', return_sequences=False), input_shape=(X_train.shape[1], X_train.shape[2])))
model_bilstm.add(Dense(32, activation='relu'))
model_bilstm.add(Dense(1))  # Output layer for RUL prediction

# Compile the model
model_bilstm.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
history = model_bilstm.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the model on the test data
test_loss, test_mae = model_bilstm.evaluate(X_test, y_test)
print(f'Test MAE: {test_mae:.4f}')

# Predict the RUL for the test data
y_pred = model_bilstm.predict(X_test).flatten()

# Calculate performance metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print performance metrics
# Out:
# Epoch 1/50
# C:\Users\saravanan013\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 353251.9062 - mae: 501.1873 - val_loss: 123227.6328 - val_mae: 294.8062
# Epoch 2/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 114509.8438 - mae: 289.5116 - val_loss: 102543.1484 - val_mae: 274.5187
# Epoch 3/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 104868.8750 - mae: 281.2624 - val_loss: 102592.3203 - val_mae: 274.6072
# Epoch 4/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 104137.4688 - mae: 280.0449 - val_loss: 102601.5312 - val_mae: 274.6251
# Epoch 5/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 104644.1406 - mae: 280.9330 - val_loss: 97958.0234 - val_mae: 268.1571
# Epoch 6/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 65513.4531 - mae: 199.5002 - val_loss: 4063.5432 - val_mae: 41.4667
# Epoch 7/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 2654.9817 - mae: 29.0771 - val_loss: 1080.8469 - val_mae: 19.6789
# Epoch 8/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 941.8809 - mae: 16.0644 - val_loss: 789.2031 - val_mae: 17.2860
# Epoch 9/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 586.7130 - mae: 12.8649 - val_loss: 478.8301 - val_mae: 13.4414
# Epoch 10/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 363.6745 - mae: 11.0956 - val_loss: 269.1065 - val_mae: 8.6421
# Epoch 11/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 240.5142 - mae: 9.0909 - val_loss: 242.9553 - val_mae: 8.5689
# Epoch 12/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 265.4602 - mae: 9.6278 - val_loss: 185.5798 - val_mae: 6.7148
# Epoch 13/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 202.8125 - mae: 8.2718 - val_loss: 201.1478 - val_mae: 8.0275
# Epoch 14/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 183.4473 - mae: 8.0852 - val_loss: 140.1591 - val_mae: 6.4030
# Epoch 15/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 131.8402 - mae: 7.3244 - val_loss: 178.4412 - val_mae: 10.0600
# Epoch 16/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 148.3559 - mae: 7.3775 - val_loss: 126.2282 - val_mae: 7.1923
# Epoch 17/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 148.8629 - mae: 8.1049 - val_loss: 321.6011 - val_mae: 15.4407
# Epoch 18/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 143.0823 - mae: 8.0538 - val_loss: 111.8768 - val_mae: 6.8495
# Epoch 19/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 154.5277 - mae: 8.3045 - val_loss: 135.0910 - val_mae: 9.0358
# Epoch 20/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 123.4771 - mae: 7.4972 - val_loss: 132.1567 - val_mae: 8.5673
# Epoch 21/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 102.5816 - mae: 7.0230 - val_loss: 89.9730 - val_mae: 5.4929
# Epoch 22/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 99.6358 - mae: 6.7981 - val_loss: 127.0747 - val_mae: 7.6660
# Epoch 23/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 104.5660 - mae: 6.6840 - val_loss: 110.7057 - val_mae: 6.8329
# Epoch 24/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 96.4951 - mae: 7.0338 - val_loss: 104.4981 - val_mae: 6.7484
# Epoch 25/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 82.5689 - mae: 6.2788 - val_loss: 82.4884 - val_mae: 5.9763
# Epoch 26/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 80.9551 - mae: 6.3016 - val_loss: 225.4845 - val_mae: 12.4563
# Epoch 27/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 104.5842 - mae: 7.1071 - val_loss: 104.2761 - val_mae: 7.6979
# Epoch 28/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 101.2870 - mae: 7.1522 - val_loss: 77.2475 - val_mae: 6.2779
# Epoch 29/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 82.8212 - mae: 6.4005 - val_loss: 150.1674 - val_mae: 9.2707
# Epoch 30/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 88.9303 - mae: 6.6911 - val_loss: 113.6707 - val_mae: 8.6828
# Epoch 31/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 112.4815 - mae: 7.9923 - val_loss: 122.5340 - val_mae: 7.4731
# Epoch 32/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 96.9068 - mae: 7.1127 - val_loss: 184.5633 - val_mae: 10.9886
# Epoch 33/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 85.7754 - mae: 6.5545 - val_loss: 172.6031 - val_mae: 10.2984
# Epoch 34/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 82.0942 - mae: 6.4311 - val_loss: 195.1937 - val_mae: 11.4848
# Epoch 35/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 85.8171 - mae: 6.5009 - val_loss: 66.9508 - val_mae: 5.6410
# Epoch 36/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 72.8295 - mae: 5.8621 - val_loss: 68.9528 - val_mae: 5.0742
# Epoch 37/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 79.9973 - mae: 6.2454 - val_loss: 71.3929 - val_mae: 5.7423
# Epoch 38/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 78.0847 - mae: 6.2873 - val_loss: 179.2435 - val_mae: 9.5330
# Epoch 39/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 175.8317 - mae: 8.8103 - val_loss: 102.6794 - val_mae: 7.2156
# Epoch 40/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 91.9253 - mae: 6.9904 - val_loss: 64.2346 - val_mae: 4.9822
# Epoch 41/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 74.7077 - mae: 6.0475 - val_loss: 59.6997 - val_mae: 4.7320
# Epoch 42/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 79.0084 - mae: 6.3023 - val_loss: 92.0548 - val_mae: 6.4986
# Epoch 43/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 91.6189 - mae: 6.7437 - val_loss: 66.2881 - val_mae: 5.0113
# Epoch 44/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 73.9573 - mae: 6.0642 - val_loss: 291.6851 - val_mae: 15.6226
# Epoch 45/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 99.0474 - mae: 7.3081 - val_loss: 110.4681 - val_mae: 8.7054
# Epoch 46/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 72.9720 - mae: 5.9622 - val_loss: 75.4539 - val_mae: 6.3877
# Epoch 47/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 83.3554 - mae: 6.5681 - val_loss: 59.5812 - val_mae: 4.6214
# Epoch 48/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 83.8816 - mae: 6.6214 - val_loss: 59.3104 - val_mae: 4.7215
# Epoch 49/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 68.5643 - mae: 5.6913 - val_loss: 61.4109 - val_mae: 4.9687
# Epoch 50/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 80.6489 - mae: 6.3870 - val_loss: 141.3867 - val_mae: 10.1380
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 142.3139 - mae: 10.3089
# Test MAE: 10.2314
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Predict the RUL for the test data
y_pred = model_bilstm.predict(X_test)

# Flatten the predictions and actual values
y_pred = y_pred.flatten()
y_test = y_test.flatten()

# Calculate standard performance metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Define a custom accuracy metric (percentage of predictions within 10% tolerance of actual value)
tolerance = 0.10  # 10% tolerance
accurate_predictions = np.sum(np.abs(y_test - y_pred) <= tolerance * y_test)
accuracy = accurate_predictions / len(y_test) * 100

# Print all performance metrics
print(f'Mean Squared Error (MSE): {mse:.4f}')
print(f'Mean Absolute Error (MAE): {mae:.4f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.4f}')
print(f'Accuracy (within 10% tolerance): {accuracy:.2f}%')

# Optional: Print the first 10 predictions vs actual values for inspection
print('\nSample Predictions vs Actual Values:')
for i in range(10):
    print(f'Actual: {y_test[i]:.2f}, Predicted: {y_pred[i]:.2f}')
# Out:
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean Squared Error (MSE): 141.3248
# Mean Absolute Error (MAE): 10.2314
# Root Mean Squared Error (RMSE): 11.8880
# Accuracy (within 10% tolerance): 93.03%
#
# Sample Predictions vs Actual Values:
# Actual: 192.00, Predicted: 193.58
# Actual: 445.00, Predicted: 458.37
# Actual: 349.00, Predicted: 357.02
# Actual: 515.00, Predicted: 520.48
# Actual: 827.00, Predicted: 818.09
# Actual: 929.00, Predicted: 943.06
# Actual: 1008.00, Predicted: 1021.10
# Actual: 273.00, Predicted: 250.63
# Actual: 74.00, Predicted: 74.67
# Actual: 341.00, Predicted: 348.67

# %%
num_samples = 100
y_test_limited = y_test[:num_samples]
y_pred_limited = y_pred[:num_samples]

# Plot Actual vs. Predicted values for the limited data
plt.figure(figsize=(10, 6))
plt.plot(y_test_limited, label='Actual RUL', marker='o')
plt.plot(y_pred_limited, label='Predicted RUL', marker='x')
plt.title('Actual vs Predicted RUL (Limited Samples)')
plt.xlabel('Sample Index')
plt.ylabel('RUL')
plt.legend()
plt.grid(True)
plt.savefig('BiLSTM.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load your dataset (adjust the file path as needed)
data = pd.read_csv('dataset.csv')  # Replace with your actual file path

# Feature selection: Drop 'RUL' for input features
X = data.drop('RUL', axis=1).values
y = data['RUL'].values

# Normalize features (MinMax scaling between 0 and 1)
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# Reshape the data into time series format for GRU (samples, timesteps, features)
TIME_STEPS = 10  # Window size

def create_sequences(X, y, time_steps=TIME_STEPS):
    X_seq, y_seq = [], []
    for i in range(len(X) - time_steps):
        X_seq.append(X[i:i + time_steps])
        y_seq.append(y[i + time_steps])
    return np.array(X_seq), np.array(y_seq)

X_seq, y_seq = create_sequences(X, y)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

# Define the GRU model
model_gru = Sequential()
model_gru.add(GRU(64, activation='tanh', input_shape=(X_train.shape[1], X_train.shape[2])))
model_gru.add(Dense(32, activation='relu'))
model_gru.add(Dense(1))  # Output layer for RUL prediction

# Compile the model
model_gru.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
history = model_gru.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the model on the test data
test_loss, test_mae = model_gru.evaluate(X_test, y_test)
print(f'Test MAE: {test_mae:.4f}')

# Predict the RUL for the test data
y_pred = model_gru.predict(X_test).flatten()

# Calculate performance metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print performance metrics
# Out:
# Epoch 1/50
# C:\Users\saravanan013\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 379108.9688 - mae: 524.0797 - val_loss: 217116.4844 - val_mae: 380.6892
# Epoch 2/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 179950.3750 - mae: 345.3835 - val_loss: 105793.6016 - val_mae: 277.6151
# Epoch 3/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 107371.0781 - mae: 283.9344 - val_loss: 102502.8750 - val_mae: 274.4291
# Epoch 4/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 103994.3203 - mae: 279.6272 - val_loss: 102522.9375 - val_mae: 274.4777
# Epoch 5/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 104388.7188 - mae: 280.0641 - val_loss: 102550.7812 - val_mae: 274.5346
# Epoch 6/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 101816.3750 - mae: 275.0818 - val_loss: 22324.4121 - val_mae: 92.3225
# Epoch 7/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13720.7734 - mae: 63.9483 - val_loss: 2246.5955 - val_mae: 23.8217
# Epoch 8/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1645.8798 - mae: 21.3172 - val_loss: 1010.2171 - val_mae: 13.8099
# Epoch 9/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 559.0696 - mae: 13.3489 - val_loss: 774.1040 - val_mae: 13.7317
# Epoch 10/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 489.7067 - mae: 11.3659 - val_loss: 566.9459 - val_mae: 10.4014
# Epoch 11/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 523.7859 - mae: 10.1946 - val_loss: 472.4075 - val_mae: 9.4829
# Epoch 12/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 331.6911 - mae: 9.1928 - val_loss: 395.7234 - val_mae: 9.5342
# Epoch 13/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 321.1972 - mae: 8.6039 - val_loss: 384.6848 - val_mae: 10.0665
# Epoch 14/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 266.1627 - mae: 8.5952 - val_loss: 294.6628 - val_mae: 6.9220
# Epoch 15/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 306.6211 - mae: 8.0797 - val_loss: 466.7498 - val_mae: 15.7728
# Epoch 16/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 400.9697 - mae: 9.1921 - val_loss: 276.0525 - val_mae: 9.5313
# Epoch 17/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 185.0397 - mae: 7.8046 - val_loss: 223.3147 - val_mae: 7.0895
# Epoch 18/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 262.0780 - mae: 8.0357 - val_loss: 331.8370 - val_mae: 12.8554
# Epoch 19/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 187.1080 - mae: 7.5921 - val_loss: 173.5612 - val_mae: 7.0377
# Epoch 20/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 194.8669 - mae: 7.3164 - val_loss: 155.0061 - val_mae: 5.8659
# Epoch 21/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 163.7931 - mae: 6.9721 - val_loss: 191.5499 - val_mae: 8.6181
# Epoch 22/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 158.1515 - mae: 7.6492 - val_loss: 215.2377 - val_mae: 9.9409
# Epoch 23/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 150.4233 - mae: 7.0448 - val_loss: 135.8176 - val_mae: 6.7488
# Epoch 24/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 138.2991 - mae: 6.9612 - val_loss: 118.4925 - val_mae: 5.8125
# Epoch 25/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 115.8976 - mae: 6.6998 - val_loss: 114.1108 - val_mae: 7.5898
# Epoch 26/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 137.8041 - mae: 7.4139 - val_loss: 129.1089 - val_mae: 7.3098
# Epoch 27/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 98.1088 - mae: 6.1836 - val_loss: 95.2850 - val_mae: 6.2686
# Epoch 28/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 112.2881 - mae: 6.9413 - val_loss: 83.3507 - val_mae: 5.6948
# Epoch 29/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 105.9747 - mae: 6.0058 - val_loss: 77.2071 - val_mae: 5.3234
# Epoch 30/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 88.3058 - mae: 6.4947 - val_loss: 96.4206 - val_mae: 6.3713
# Epoch 31/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 91.7783 - mae: 6.4073 - val_loss: 120.5203 - val_mae: 7.6690
# Epoch 32/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 92.5506 - mae: 6.5158 - val_loss: 230.1167 - val_mae: 12.9159
# Epoch 33/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 109.3927 - mae: 7.3260 - val_loss: 74.2010 - val_mae: 5.4492
# Epoch 34/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 94.6358 - mae: 6.3561 - val_loss: 108.3641 - val_mae: 8.2175
# Epoch 35/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 89.0686 - mae: 6.5733 - val_loss: 214.7460 - val_mae: 11.9323
# Epoch 36/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 97.8852 - mae: 6.9626 - val_loss: 71.1563 - val_mae: 5.4249
# Epoch 37/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 80.1075 - mae: 6.1188 - val_loss: 129.6639 - val_mae: 8.6601
# Epoch 38/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 96.2577 - mae: 7.1120 - val_loss: 143.8264 - val_mae: 8.8855
# Epoch 39/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 98.1202 - mae: 6.8481 - val_loss: 142.5263 - val_mae: 10.6669
# Epoch 40/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 79.9983 - mae: 6.0333 - val_loss: 122.1367 - val_mae: 9.2557
# Epoch 41/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 79.2464 - mae: 6.1955 - val_loss: 86.2861 - val_mae: 5.9006
# Epoch 42/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 85.2286 - mae: 6.4159 - val_loss: 92.8192 - val_mae: 7.9063
# Epoch 43/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 77.7850 - mae: 6.0473 - val_loss: 67.7676 - val_mae: 5.3206
# Epoch 44/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 74.9528 - mae: 5.8865 - val_loss: 107.1245 - val_mae: 8.8571
# Epoch 45/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 77.6405 - mae: 5.9540 - val_loss: 89.2135 - val_mae: 6.4872
# Epoch 46/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 87.4692 - mae: 6.6344 - val_loss: 66.4938 - val_mae: 4.5615
# Epoch 47/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 77.8563 - mae: 6.1125 - val_loss: 68.2643 - val_mae: 5.1231
# Epoch 48/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 76.3383 - mae: 5.9695 - val_loss: 77.3826 - val_mae: 5.3734
# Epoch 49/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 87.1734 - mae: 6.5190 - val_loss: 92.3689 - val_mae: 6.7755
# Epoch 50/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 81.0498 - mae: 6.2850 - val_loss: 69.2510 - val_mae: 5.7987
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 74.4035 - mae: 5.8458
# Test MAE: 5.8280
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Predict the RUL for the test data
y_pred = model_gru.predict(X_test)

# Flatten the predictions and actual values
y_pred = y_pred.flatten()
y_test = y_test.flatten()

# Calculate standard performance metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Define a custom accuracy metric (percentage of predictions within 10% tolerance of actual value)
tolerance = 0.10  # 10% tolerance
accurate_predictions = np.sum(np.abs(y_test - y_pred) <= tolerance * y_test)
accuracy = accurate_predictions / len(y_test) * 100

# Print all performance metrics
print(f'Mean Squared Error (MSE): {mse:.4f}')
print(f'Mean Absolute Error (MAE): {mae:.4f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.4f}')
print(f'Accuracy (within 10% tolerance): {accuracy:.2f}%')

# Optional: Print the first 10 predictions vs actual values for inspection
print('\nSample Predictions vs Actual Values:')
for i in range(10):
    print(f'Actual: {y_test[i]:.2f}, Predicted: {y_pred[i]:.2f}')
# Out:
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Mean Squared Error (MSE): 71.7379
# Mean Absolute Error (MAE): 5.8280
# Root Mean Squared Error (RMSE): 8.4698
# Accuracy (within 10% tolerance): 95.68%
#
# Sample Predictions vs Actual Values:
# Actual: 192.00, Predicted: 191.93
# Actual: 445.00, Predicted: 455.04
# Actual: 349.00, Predicted: 351.83
# Actual: 515.00, Predicted: 514.00
# Actual: 827.00, Predicted: 811.07
# Actual: 929.00, Predicted: 928.66
# Actual: 1008.00, Predicted: 1009.30
# Actual: 273.00, Predicted: 247.60
# Actual: 74.00, Predicted: 81.34
# Actual: 341.00, Predicted: 342.34

# %%
num_samples = 100
y_test_limited = y_test[:num_samples]
y_pred_limited = y_pred[:num_samples]

# Plot Actual vs. Predicted values for the limited data
plt.figure(figsize=(10, 6))
plt.plot(y_test_limited, label='Actual RUL', marker='o')
plt.plot(y_pred_limited, label='Predicted RUL', marker='x')
plt.title('Actual vs Predicted RUL (Limited Samples)')
plt.xlabel('Sample Index')
plt.ylabel('RUL')
plt.legend()
plt.grid(True)
plt.savefig('GRU.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Bidirectional
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load your dataset (adjust the file path as needed)
data = pd.read_csv('dataset.csv')  # Replace with your actual file path

# Feature selection: Drop 'RUL' for input features
X = data.drop('RUL', axis=1).values
y = data['RUL'].values

# Normalize features (MinMax scaling between 0 and 1)
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# Reshape the data into time series format for BiGRU (samples, timesteps, features)
TIME_STEPS = 10  # Window size

def create_sequences(X, y, time_steps=TIME_STEPS):
    X_seq, y_seq = [], []
    for i in range(len(X) - time_steps):
        X_seq.append(X[i:i + time_steps])
        y_seq.append(y[i + time_steps])
    return np.array(X_seq), np.array(y_seq)

X_seq, y_seq = create_sequences(X, y)

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

# Define the BiGRU model
model_bigru = Sequential()
model_bigru.add(Bidirectional(GRU(64, activation='tanh', return_sequences=False), input_shape=(X_train.shape[1], X_train.shape[2])))
model_bigru.add(Dense(32, activation='relu'))
model_bigru.add(Dense(1))  # Output layer for RUL prediction

# Compile the model
model_bigru.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
history = model_bigru.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the model on the test data
test_loss, test_mae = model_bigru.evaluate(X_test, y_test)
print(f'Test MAE: {test_mae:.4f}')

# Predict the RUL for the test data
y_pred = model_bigru.predict(X_test).flatten()
# Out:
# Epoch 1/50
# C:\Users\saravanan013\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 359762.7500 - mae: 508.0755 - val_loss: 145132.2812 - val_mae: 315.5798
# Epoch 2/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 124326.8359 - mae: 298.0281 - val_loss: 102492.6719 - val_mae: 274.3421
# Epoch 3/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 103337.3750 - mae: 279.1496 - val_loss: 102528.6641 - val_mae: 274.4904
# Epoch 4/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 104736.9922 - mae: 280.1189 - val_loss: 102547.9141 - val_mae: 274.5789
# Epoch 5/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 75547.5781 - mae: 217.5501 - val_loss: 4922.1938 - val_mae: 48.1311
# Epoch 6/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 2756.8013 - mae: 31.6183 - val_loss: 1003.5491 - val_mae: 23.8655
# Epoch 7/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 660.4454 - mae: 16.7452 - val_loss: 288.1338 - val_mae: 11.5437
# Epoch 8/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 309.9075 - mae: 11.6192 - val_loss: 202.7204 - val_mae: 10.9346
# Epoch 9/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 172.9615 - mae: 9.3340 - val_loss: 179.9973 - val_mae: 10.8345
# Epoch 10/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 112.7735 - mae: 7.4376 - val_loss: 156.7555 - val_mae: 9.0353
# Epoch 11/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 116.2742 - mae: 7.6551 - val_loss: 80.4203 - val_mae: 5.5082
# Epoch 12/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 107.6637 - mae: 7.3595 - val_loss: 111.9465 - val_mae: 7.0138
# Epoch 13/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 98.4435 - mae: 7.0213 - val_loss: 99.0852 - val_mae: 6.9580
# Epoch 14/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 97.8707 - mae: 7.0617 - val_loss: 101.0371 - val_mae: 7.3866
# Epoch 15/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 89.4815 - mae: 6.6234 - val_loss: 73.6830 - val_mae: 5.3214
# Epoch 16/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 90.6686 - mae: 6.8653 - val_loss: 111.9445 - val_mae: 7.3575
# Epoch 17/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 85.4460 - mae: 6.5760 - val_loss: 87.3213 - val_mae: 7.3383
# Epoch 18/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 76.0164 - mae: 6.0526 - val_loss: 113.9183 - val_mae: 8.1119
# Epoch 19/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 82.0393 - mae: 6.3240 - val_loss: 85.0394 - val_mae: 6.0375
# Epoch 20/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 84.9630 - mae: 6.5095 - val_loss: 95.4285 - val_mae: 6.6481
# Epoch 21/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 86.5904 - mae: 6.5983 - val_loss: 83.2819 - val_mae: 7.4255
# Epoch 22/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 71.9889 - mae: 5.8308 - val_loss: 71.9556 - val_mae: 5.4815
# Epoch 23/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 96.1757 - mae: 7.0464 - val_loss: 195.5044 - val_mae: 12.2495
# Epoch 24/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 105.9592 - mae: 7.5588 - val_loss: 98.0247 - val_mae: 6.8659
# Epoch 25/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 85.1653 - mae: 6.6220 - val_loss: 65.4766 - val_mae: 4.9555
# Epoch 26/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 81.9409 - mae: 6.4590 - val_loss: 180.3385 - val_mae: 10.8313
# Epoch 27/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 83.1167 - mae: 6.5488 - val_loss: 73.6778 - val_mae: 5.3089
# Epoch 28/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 86.1905 - mae: 6.6128 - val_loss: 80.8596 - val_mae: 6.2732
# Epoch 29/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 80.3727 - mae: 6.3379 - val_loss: 56.2285 - val_mae: 4.5041
# Epoch 30/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 76.1256 - mae: 6.0714 - val_loss: 68.8051 - val_mae: 4.8395
# Epoch 31/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 71.2422 - mae: 5.7405 - val_loss: 107.4162 - val_mae: 7.4219
# Epoch 32/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 76.9627 - mae: 6.2705 - val_loss: 60.9327 - val_mae: 4.7436
# Epoch 33/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 81.4873 - mae: 6.5145 - val_loss: 60.7408 - val_mae: 5.4324
# Epoch 34/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 76.1081 - mae: 6.1121 - val_loss: 270.1651 - val_mae: 11.6186
# Epoch 35/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 118.3379 - mae: 7.5207 - val_loss: 71.4615 - val_mae: 5.5340
# Epoch 36/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 76.8844 - mae: 6.1008 - val_loss: 71.3128 - val_mae: 5.3101
# Epoch 37/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 79.7363 - mae: 6.2921 - val_loss: 116.8706 - val_mae: 7.8843
# Epoch 38/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 82.3380 - mae: 6.5059 - val_loss: 70.6912 - val_mae: 5.2534
# Epoch 39/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 81.3672 - mae: 6.4682 - val_loss: 64.3248 - val_mae: 5.1944
# Epoch 40/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 73.9846 - mae: 5.9264 - val_loss: 63.1653 - val_mae: 5.5570
# Epoch 41/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 70.5841 - mae: 5.8816 - val_loss: 103.5883 - val_mae: 7.2649
# Epoch 42/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 86.9709 - mae: 6.6389 - val_loss: 58.2648 - val_mae: 5.5295
# Epoch 43/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 68.5329 - mae: 5.7349 - val_loss: 68.6654 - val_mae: 5.0357
# Epoch 44/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 67.5446 - mae: 5.5813 - val_loss: 71.2013 - val_mae: 6.7514
# Epoch 45/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 75.4282 - mae: 6.1291 - val_loss: 59.3153 - val_mae: 5.2838
# Epoch 46/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 75.6453 - mae: 6.2201 - val_loss: 100.8480 - val_mae: 8.0692
# Epoch 47/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 71.3530 - mae: 5.9275 - val_loss: 82.4087 - val_mae: 6.5952
# Epoch 48/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 71.8137 - mae: 5.8549 - val_loss: 66.9607 - val_mae: 4.9744
# Epoch 49/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 72.3528 - mae: 5.8836 - val_loss: 54.0440 - val_mae: 4.4709
# Epoch 50/50
# 302/302 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 69.3260 - mae: 5.7697 - val_loss: 53.6669 - val_mae: 4.2077
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51.8527 - mae: 4.1731
# Test MAE: 4.2328
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Predict the RUL for the test data


# Flatten the predictions and actual values
y_pred = y_pred.flatten()
y_test = y_test.flatten()

# Calculate standard performance metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Define a custom accuracy metric (percentage of predictions within 10% tolerance of actual value)
tolerance = 0.10  # 10% tolerance
accurate_predictions = np.sum(np.abs(y_test - y_pred) <= tolerance * y_test)
accuracy = accurate_predictions / len(y_test) * 100

# Print all performance metrics
print(f'Mean Squared Error (MSE): {mse:.4f}')
print(f'Mean Absolute Error (MAE): {mae:.4f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.4f}')
print(f'Accuracy (within 10% tolerance): {accuracy:.2f}%')

# Optional: Print the first 10 predictions vs actual values for inspection
print('\nSample Predictions vs Actual Values:')
for i in range(10):
    print(f'Actual: {y_test[i]:.2f}, Predicted: {y_pred[i]:.2f}')
# Out:
# Mean Squared Error (MSE): 52.9046
# Mean Absolute Error (MAE): 4.2328
# Root Mean Squared Error (RMSE): 7.2736
# Accuracy (within 10% tolerance): 96.08%
#
# Sample Predictions vs Actual Values:
# Actual: 192.00, Predicted: 191.61
# Actual: 445.00, Predicted: 451.90
# Actual: 349.00, Predicted: 350.47
# Actual: 515.00, Predicted: 510.96
# Actual: 827.00, Predicted: 803.44
# Actual: 929.00, Predicted: 925.00
# Actual: 1008.00, Predicted: 1009.04
# Actual: 273.00, Predicted: 248.79
# Actual: 74.00, Predicted: 79.72
# Actual: 341.00, Predicted: 343.65

# %%
# Limit the data to the first 100 samples for plotting
num_samples = 100
y_test_limited = y_test[:num_samples]
y_pred_limited = y_pred[:num_samples]

# Plot Actual vs. Predicted values for the limited data
plt.figure(figsize=(10, 6))
plt.plot(y_test_limited, label='Actual RUL', marker='o')
plt.plot(y_pred_limited, label='Predicted RUL', marker='x')
plt.title('Actual vs Predicted RUL (Limited Samples)')
plt.xlabel('Sample Index')
plt.ylabel('RUL')
plt.legend()
plt.grid(True)
plt.savefig('BiGRU.png', dpi=600, bbox_inches='tight')
plt.show()
